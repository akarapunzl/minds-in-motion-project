# %%
#importing and pre-processing data
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix


from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# %%
# Read the data into a Pandas DataFrame
loan_info_df = pd.read_json('Resources/loan_approval_dataset.json')
loan_info_df.set_index('Id', inplace=True)
loan_info_df.head(35)
# Out:
#      Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# Id
# 1   1303834   23           3         single          rented            no
# 2   7574516   40          10         single          rented            no
# 3   3991815   66           4        married          rented            no
# 4   6256451   41           2         single          rented           yes
# 5   5768871   47          11         single          rented            no
# 6   6915937   64           0         single          rented            no
# 7   3954973   58          14        married          rented            no
# 8   1706172   33           2         single          rented            no
# 9   7566849   24          17         single          rented           yes
# 10  8964846   23          12         single          rented            no
# 11  4634680   78           7         single          rented            no
# 12  6623263   22           4         single          rented            no
# 13  9120988   28           9         single          rented            no
# 14  8043880   57          12         single          rented            no
# 15  9420838   48           6         single          rented            no
# 16  5694236   39           2        married          rented           yes
# 17  7315840   71           8        married          rented            no
# 18  3666346   56          12         single          rented            no
# 19  2241112   28           8         single          rented            no
# 20  5431918   40           1         single          rented            no
# 21  9225468   54          14         single          rented            no
# 22  6506739   50           4         single          rented            no
# 23  9157379   72          13         single          rented           yes
# 24  9236505   36          19         single          rented            no
# 25  1065465   23          15        married          rented            no
# 26  1797876   76          20         single    norent_noown            no
# 27  6063428   38           6        married          rented            no
# 28  9643150   24          13         single          rented            no
# 29  8832725   64           5         single          rented            no
# 30  4386333   31          16         single          rented            no
# 31  3939397   52          19         single          rented           yes
# 32  6944134   59           5         single           owned            no
# 33  4128828   21          10         single          rented            no
# 34  5023035   26          10         single          rented           yes
# 35  9086933   55           7         single          rented            no
#
#                     Profession                 CITY           STATE  \
# Id
# 1          Mechanical_engineer                 Rewa  Madhya_Pradesh
# 2           Software_Developer             Parbhani     Maharashtra
# 3             Technical_writer            Alappuzha          Kerala
# 4           Software_Developer          Bhubaneswar          Odisha
# 5                Civil_servant  Tiruchirappalli[10]      Tamil_Nadu
# 6                Civil_servant              Jalgaon     Maharashtra
# 7                    Librarian             Tiruppur      Tamil_Nadu
# 8                    Economist             Jamnagar         Gujarat
# 9             Flight_attendant              Kota[6]       Rajasthan
# 10                   Architect           Karimnagar       Telangana
# 11            Flight_attendant          Hajipur[31]           Bihar
# 12                    Designer                Adoni  Andhra_Pradesh
# 13                   Physician            Erode[17]      Tamil_Nadu
# 14           Financial_Analyst               Kollam          Kerala
# 15            Technical_writer              Madurai      Tamil_Nadu
# 16                   Economist      Anantapuram[24]  Andhra_Pradesh
# 17      Air_traffic_controller            Kamarhati     West_Bengal
# 18                  Politician             Bhusawal     Maharashtra
# 19              Police_officer                Sirsa         Haryana
# 20                      Artist            Amaravati  Andhra_Pradesh
# 21                    Surveyor         Secunderabad       Telangana
# 22                  Politician            Ahmedabad         Gujarat
# 23             Design_Engineer                Ajmer       Rajasthan
# 24           Chemical_engineer               Ongole  Andhra_Pradesh
# 25               Hotel_Manager          Miryalaguda       Telangana
# 26         Mechanical_engineer            Erode[17]      Tamil_Nadu
# 27                     Dentist             Ambattur      Tamil_Nadu
# 28                    Comedian               Indore  Madhya_Pradesh
# 29         Biomedical_Engineer          Pondicherry      Puducherry
# 30                   Physician              Shimoga       Karnataka
# 31            Flight_attendant              Chennai      Tamil_Nadu
# 32            Graphic_Designer             Gulbarga       Karnataka
# 33  Computer_hardware_engineer              Khammam       Telangana
# 34          Petroleum_Engineer              Madurai      Tamil_Nadu
# 35      Air_traffic_controller           Saharanpur   Uttar_Pradesh
#
#     CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  Risk_Flag
# Id
# 1                 3                 13          0
# 2                 9                 13          0
# 3                 4                 10          0
# 4                 2                 12          1
# 5                 3                 14          1
# 6                 0                 12          0
# 7                 8                 12          0
# 8                 2                 14          0
# 9                11                 11          0
# 10                5                 13          0
# 11                7                 12          0
# 12                4                 14          0
# 13                9                 12          0
# 14                8                 10          0
# 15                6                 10          1
# 16                2                 10          0
# 17                8                 14          0
# 18               12                 11          1
# 19                6                 14          0
# 20                1                 14          0
# 21                8                 10          0
# 22                4                 11          0
# 23                9                 10          0
# 24                6                 14          0
# 25                4                 12          0
# 26               11                 14          0
# 27                6                 13          0
# 28                6                 14          0
# 29                5                 11          1
# 30                3                 12          0
# 31                3                 10          0
# 32                5                 11          0
# 33               10                 12          0
# 34                9                 13          0
# 35                7                 13          0

# %%
loan_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252000 entries, 0 to 251999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Id                 252000 non-null  int64
#  1   Income             252000 non-null  int64
#  2   Age                252000 non-null  int64
#  3   Experience         252000 non-null  int64
#  4   Married/Single     252000 non-null  object
#  5   House_Ownership    252000 non-null  object
#  6   Car_Ownership      252000 non-null  object
#  7   Profession         252000 non-null  object
#  8   CITY               252000 non-null  object
#  9   STATE              252000 non-null  object
#  10  CURRENT_JOB_YRS    252000 non-null  int64
#  11  CURRENT_HOUSE_YRS  252000 non-null  int64
#  12  Risk_Flag          252000 non-null  int64
# dtypes: int64(7), object(6)
# memory usage: 26.9+ MB

# %%
loan_info_df.columns
# Out:
# Index(['Id', 'Income', 'Age', 'Experience', 'Married/Single',
#        'House_Ownership', 'Car_Ownership', 'Profession', 'CITY', 'STATE',
#        'CURRENT_JOB_YRS', 'CURRENT_HOUSE_YRS', 'Risk_Flag'],
#       dtype='object')
